# %%
import os
import pandas as pd

df = pd.read_csv("C:\\Users\\ABHIJEET\\OneDrive\\Fore\\Trimester 1\\Python\\Sample - Superstore.csv", encoding='ISO-8859-1')
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
sample_df = df.sample(n = 2000,replace = False, random_state=55002)
sample_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1091    1092  CA-2015-143490   12/6/2015  12/13/2015  Standard Class
# 4721    4722  CA-2014-106229    6/7/2014   6/11/2014    Second Class
# 4668    4669  US-2017-133200    5/6/2017   5/11/2017  Standard Class
# 2018    2019  CA-2015-113110   3/19/2015   3/23/2015  Standard Class
# 3294    3295  CA-2014-138023   8/15/2014   8/18/2014     First Class
# ...      ...             ...         ...         ...             ...
# 4699    4700  CA-2017-140298   5/11/2017   5/17/2017  Standard Class
# 7895    7896  CA-2017-124744   6/21/2017   6/25/2017  Standard Class
# 1673    1674  CA-2015-150560  12/11/2015  12/12/2015     First Class
# 4558    4559  CA-2014-127383  12/31/2014    1/5/2015  Standard Class
# 2594    2595  CA-2017-149048   5/13/2017   5/17/2017  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 1091    NP-18325       Naresj Patel     Consumer  United States
# ...

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 1091 to 2594
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         2000 non-null   int64
#  1   Order ID       2000 non-null   object
#  2   Order Date     2000 non-null   object
#  3   Ship Date      2000 non-null   object
#  4   Ship Mode      2000 non-null   object
#  5   Customer ID    2000 non-null   object
#  6   Customer Name  2000 non-null   object
#  7   Segment        2000 non-null   object
#  8   Country        2000 non-null   object
#  9   City           2000 non-null   object
#  10  State          2000 non-null   object
#  11  Postal Code    2000 non-null   int64
#  12  Region         2000 non-null   object
#  13  Product ID     2000 non-null   object
#  14  Category       2000 non-null   object
#  15  Sub-Category   2000 non-null   object
#  16  Product Name   2000 non-null   object
# ...

# %%
sample_df.describe()
# Out:
#             Row ID   Postal Code        Sales     Quantity     Discount  \
# count  2000.000000   2000.000000  2000.000000  2000.000000  2000.000000
# mean   4988.823500  54849.206000   220.940689     3.786000     0.157210
# std    2861.948472  31985.234673   520.186436     2.229953     0.207789
# min       1.000000   1453.000000     0.444000     1.000000     0.000000
# 25%    2565.750000  23602.000000    17.940000     2.000000     0.000000
# 50%    4909.000000  55078.500000    54.256000     3.000000     0.200000
# 75%    7492.000000  90004.000000   209.970000     5.000000     0.200000
# max    9994.000000  99301.000000  9449.950000    14.000000     0.800000
#
#             Profit
# count  2000.000000
# mean     28.159083
# std     193.537414
# min   -3399.980000
# 25%       1.877000
# 50%       9.154950
# 75%      31.018400
# max    4630.475500

# %%
sample_df.head()
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID    Customer Name    Segment        Country            City  ... Postal Code   Region       Product ID         Category Sub-Category                                    Product Name    Sales  Quantity  Discount    Profit
# 1091    1092  CA-2015-143490  12/6/2015  12/13/2015  Standard Class    NP-18325     Naresj Patel   Consumer  United States       San Diego  ...       92105     West  OFF-AR-10002952  Office Supplies          Art  Stanley Contemporary Battery Pencil Sharpeners  120.150         9       0.0   33.6420
# 4721    4722  CA-2014-106229   6/7/2014   6/11/2014    Second Class    NR-18550     Nick Radford   Consumer  United States          Aurora  ...       60505  Central  FUR-TA-10002041        Furniture       Tables        Bevis Round Conference Table Top, X-Base  268.935         3       0.5 -209.7693
# ...

# %%
sample_df.tail(2)
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode Customer ID    Customer Name    Segment        Country      City  ... Postal Code   Region       Product ID         Category Sub-Category                                       Product Name    Sales  Quantity  Discount   Profit
# 4558    4559  CA-2014-127383  12/31/2014   1/5/2015  Standard Class    CM-11815  Candace McMahon  Corporate  United States   El Paso  ...       79907  Central  OFF-EN-10004773  Office Supplies    Envelopes                                    Staple envelope   49.568         2       0.2  17.9684
# 2594    2595  CA-2017-149048   5/13/2017  5/17/2017  Standard Class    BM-11650       Brian Moss  Corporate  United States  Columbus  ...       47201  Central  OFF-EN-10003296  Office Supplies    Envelopes  Tyvek Side-Opening Peel & Seel Expanding Envel...  180.960         2       0.0  81.4320
#
# [2 rows x 21 columns]

# %%
# Figure out what are non categorical varible, then find categorical, then ordinal and nominal
# Categorical varible Nominal: Order Date, Ship Date, Ship Mode, Customer Name, Segment, Postal Code, State,Country, City, Region, Product Name
# Categorical varible Ordinal: Quantity, Discount, Sales
# Non Categorical varible: 	Profit, Category, Sub-Category
